# %%
import pandas as pd
import numpy as np
import xlrd

# %%
aba = pd.read_excel('SISECAM FURNACE DATA (CONTAINER) ABA.XLSX')

# %%
aba.head()
# Out:
#         DATE GLASS COLOR  PULL (kg/day)  PULL (ton/m2.day)  CULLET (%)  \
# 0 2020-01-01       FLINT    445382.0040                NaN   10.003913
# 1 2020-01-02       FLINT    461392.3982                NaN    9.948109
# 2 2020-01-03       FLINT    459750.5030                NaN   10.004327
# 3 2020-01-04       FLINT    441903.0578                NaN    8.837440
# 4 2020-01-05       FLINT    441964.2880                NaN    7.983750
#
#    BATCH HUMIDITY (%)  BATCH TEMPERATURE (C)  FURNACE INLET PRESSURE mmH2O  \
# 0            3.516667              32.666667                          0.05
# 1            3.190000              33.333333                          0.05
# 2            2.870000              30.000000                          0.13
# 3            3.113333              33.000000                          0.01
# 4            3.116667              33.000000                          0.10
#
#    OXYGEN (%) TOP LEFT  OXYGEN (%) TOP RIGHT  ...  \
# ...

# %%
aba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 96 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   DATE                                  366 non-null    datetime64[ns]
#  1   GLASS COLOR                           202 non-null    object
#  2   PULL (kg/day)                         366 non-null    float64
#  3   PULL (ton/m2.day)                     0 non-null      float64
#  4   CULLET (%)                            358 non-null    float64
#  5   BATCH HUMIDITY (%)                    366 non-null    float64
#  6   BATCH TEMPERATURE (C)                 366 non-null    float64
#  7   FURNACE INLET PRESSURE mmH2O          366 non-null    float64
#  8   OXYGEN (%) TOP LEFT                   29 non-null     float64
#  9   OXYGEN (%) TOP RIGHT                  29 non-null     float64
# ...

# %%
abb = pd.read_excel('SISECAM FURNACE DATA (CONTAINER) ABB.xlsx')

# %%
abb.head()
# Out:
#         DATE GLASS COLOR  PULL (kg/day)  PULL (ton/m2.day)  CULLET (%)  \
# 0 2020-01-01    IR-GREEN    494166.8720                NaN   59.998719
# 1 2020-01-02    IR-GREEN    494259.1050                NaN   60.005461
# 2 2020-01-03    IR-GREEN    494065.4400                NaN   58.680956
# 3 2020-01-04    IR-GREEN    494242.1500                NaN   56.382880
# 4 2020-01-05    IR-GREEN    495366.9068                NaN   55.022745
#
#    BATCH HUMIDITY (%)  BATCH TEMPERATURE (C)  FURNACE INLET PRESSURE mmH2O  \
# 0            3.230000              36.000000                         -1.01
# 1            3.193333              34.333333                         -0.96
# 2            3.123333              35.333333                         -1.02
# 3            3.116667              35.333333                         -0.97
# 4            3.263333              34.000000                         -0.98
#
#    OXYGEN (%) TOP LEFT  OXYGEN (%) TOP RIGHT  ...  \
# ...

# %%
abb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 96 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   DATE                                  366 non-null    datetime64[ns]
#  1   GLASS COLOR                           202 non-null    object
#  2   PULL (kg/day)                         366 non-null    float64
#  3   PULL (ton/m2.day)                     0 non-null      float64
#  4   CULLET (%)                            363 non-null    float64
#  5   BATCH HUMIDITY (%)                    366 non-null    float64
#  6   BATCH TEMPERATURE (C)                 366 non-null    float64
#  7   FURNACE INLET PRESSURE mmH2O          366 non-null    float64
#  8   OXYGEN (%) TOP LEFT                   29 non-null     float64
#  9   OXYGEN (%) TOP RIGHT                  29 non-null     float64
# ...

# %%
abc = pd.read_excel('SISECAM FURNACE DATA (CONTAINER) ABC.xlsx')

# %%
abc.head()
# Out:
#         DATE GLASS COLOR  PULL (kg/day)  PULL (ton/m2.day)  CULLET (%)  \
# 0 2020-01-01    IR-GREEN    393352.4410                NaN   78.996803
# 1 2020-01-02    IR-GREEN    389169.9746                NaN   78.754456
# 2 2020-01-03    IR-GREEN    382096.8278                NaN   78.730561
# 3 2020-01-04    IR-GREEN    377578.1660                NaN   75.049644
# 4 2020-01-05    IR-GREEN    377689.8300                NaN   74.956735
#
#    BATCH HUMIDITY (%)  BATCH TEMPERATURE (C)  FURNACE INLET PRESSURE mmH2O  \
# 0            3.700000              35.333333                          0.20
# 1            3.573333              35.666667                          0.18
# 2            3.613333              36.333333                          0.23
# 3            3.633333              36.000000                          0.20
# 4            3.503333              33.333333                          0.21
#
#    OXYGEN (%) TOP LEFT  OXYGEN (%) TOP RIGHT  ...  \
# ...

# %%
abc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 96 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   DATE                                  366 non-null    datetime64[ns]
#  1   GLASS COLOR                           202 non-null    object
#  2   PULL (kg/day)                         366 non-null    float64
#  3   PULL (ton/m2.day)                     0 non-null      float64
#  4   CULLET (%)                            358 non-null    float64
#  5   BATCH HUMIDITY (%)                    366 non-null    float64
#  6   BATCH TEMPERATURE (C)                 366 non-null    float64
#  7   FURNACE INLET PRESSURE mmH2O          366 non-null    float64
#  8   OXYGEN (%) TOP LEFT                   29 non-null     float64
#  9   OXYGEN (%) TOP RIGHT                  29 non-null     float64
# ...

# %%
abc.to_excel('harman_analiziC.xlsx',index=True)

# %%
c= pd.read_excel('cam_analiziC.xlsx')

# %%
c.head(5)
# Out:
#    Unnamed: 0 Fırın Numunenin Tarihi     SiO2     Al2O3     Fe2O3      TiO2  \
# 0           0     C        2019-01-02  68.928      1.89     0.233     0.059
# 1           1     C        2019-01-03  69.032      1.86     0.259     0.059
# 2           2     C        2019-01-04  69.059      1.86     0.248     0.058
# 3           3     C        2019-01-05  69.042      1.84     0.242     0.057
# 4           4     C        2019-01-06  68.950      1.84     0.238     0.057
#
#       CaO      MgO      Na2O  ...  Cr2O3  Pb (ppm)  CoO (ppm)  Açıklama  \
# 0   10.00     3.02     15.05  ...  0.230        47        3.0  08:00:00
# 1    9.95     3.06     14.99  ...  0.220        61        6.0  08:00:00
# 2    9.94     3.06     15.00  ...  0.225        51        4.0  08:00:00
# 3    9.97     3.05     15.00  ...  0.229        65        9.0  08:00:00
# 4   10.01     3.05     15.04  ...  0.235        50        7.0  08:00:00
#
#    Geliş Tarihi Rapor Tarihi Rapor No Numune No Analizi Yapan  \
# ...

# %%
abd = pd.read_excel('SISECAM FURNACE DATA (CONTAINER) ABD.xlsx')

# %%
abd.head()
# Out:
#         DATE GLASS COLOR  PULL (kg/day)  PULL (ton/m2.day)  CULLET (%)  \
# 0 2020-01-01    UV-GREEN    395484.9264                NaN   59.905969
# 1 2020-01-02    UV-GREEN    393348.3208                NaN   59.526839
# 2 2020-01-03    UV-GREEN    389255.8994                NaN   59.279610
# 3 2020-01-04    UV-GREEN    389466.8816                NaN   58.443992
# 4 2020-01-05    UV-GREEN    390057.9626                NaN   58.019790
#
#    BATCH HUMIDITY (%)  BATCH TEMPERATURE (C)  FURNACE INLET PRESSURE mmH2O  \
# 0            3.763333              36.333333                         -0.06
# 1            3.606667              36.333333                          0.04
# 2            3.593333              35.333333                          0.03
# 3            3.600000              37.333333                          0.04
# 4            3.580000              35.666667                          0.05
#
#    OXYGEN (%) TOP LEFT  OXYGEN (%) TOP RIGHT  ...  \
# ...

# %%
abd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 96 columns):
# DATE                                    366 non-null datetime64[ns]
# GLASS COLOR                             366 non-null object
# PULL (kg/day)                           366 non-null float64
# PULL (ton/m2.day)                       0 non-null float64
# CULLET (%)                              357 non-null float64
# BATCH HUMIDITY (%)                      366 non-null float64
# BATCH TEMPERATURE (C)                   366 non-null float64
# FURNACE INLET PRESSURE mmH2O            366 non-null float64
# OXYGEN (%) TOP LEFT                     31 non-null float64
# OXYGEN (%) TOP RIGHT                    31 non-null float64
# OXYGEN (%) BOTTOM LEFT                  0 non-null float64
# OXYGEN (%) BOTTOM RIGHT                 0 non-null float64
# CO (ppm) TOP LEFT                       0 non-null float64
# CO (ppm) TOP RIGHT                      0 non-null float64
# ...

# %%
f,ax = plt.subplots(figsize=(15, 15))
sns.heatmap(df_liste1.drop(["Fırın"], axis=1).corr(), annot=True, linewidths=.3, fmt= '.2f',ax=ax)
plt.show()

# %%
f,ax = plt.subplots(figsize=(15, 15))
sns.heatmap(df_liste1.drop(["Fırın"], axis=1).corr(), annot=True, linewidths=.3, fmt= '.2f',ax=ax)
plt.show()

# %%
f,ax = plt.subplots(figsize=(15, 15))
sns.heatmap(df_liste1.drop(["Fırın"], axis=1).corr(), annot=True, linewidths=.3, fmt= '.2f',ax=ax)
plt.show()

# %%
harman_list = pd.concat([aba, abb, abc, abd],axis=0)

# %%
harman_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1464 entries, 0 to 365
# Data columns (total 96 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   DATE                                  1464 non-null   datetime64[ns]
#  1   GLASS COLOR                           972 non-null    object
#  2   PULL (kg/day)                         1464 non-null   float64
#  3   PULL (ton/m2.day)                     0 non-null      float64
#  4   CULLET (%)                            1436 non-null   float64
#  5   BATCH HUMIDITY (%)                    1464 non-null   float64
#  6   BATCH TEMPERATURE (C)                 1464 non-null   float64
#  7   FURNACE INLET PRESSURE mmH2O          1464 non-null   float64
#  8   OXYGEN (%) TOP LEFT                   118 non-null    float64
#  9   OXYGEN (%) TOP RIGHT                  118 non-null    float64
# ...

# %%
harman_list.describe()
# Out:
#        PULL (kg/day)  PULL (ton/m2.day)   CULLET (%)  BATCH HUMIDITY (%)  \
# count    1464.000000                0.0  1436.000000         1464.000000
# mean   222428.953881                NaN    25.441366            1.742787
# std    206593.562496                NaN    28.260985            1.644393
# min         0.000000                NaN     0.000000            0.000000
# 25%         0.000000                NaN     0.000000            0.000000
# 50%    357769.222000                NaN     9.998933            2.520000
# 75%    407007.258350                NaN    49.993318            3.306667
# max    509052.240000                NaN    80.991826           14.310000
#
#        BATCH TEMPERATURE (C)  FURNACE INLET PRESSURE mmH2O  \
# count            1464.000000                   1464.000000
# mean               19.494010                     -0.097726
# std                18.278846                      0.369037
# min                 0.000000                     -1.150000
# ...

# %%
harman_list.head()
# Out:
#         DATE GLASS COLOR  PULL (kg/day)  PULL (ton/m2.day)  CULLET (%)  \
# 0 2020-01-01       FLINT    445382.0040                NaN   10.003913
# 1 2020-01-02       FLINT    461392.3982                NaN    9.948109
# 2 2020-01-03       FLINT    459750.5030                NaN   10.004327
# 3 2020-01-04       FLINT    441903.0578                NaN    8.837440
# 4 2020-01-05       FLINT    441964.2880                NaN    7.983750
#
#    BATCH HUMIDITY (%)  BATCH TEMPERATURE (C)  FURNACE INLET PRESSURE mmH2O  \
# 0            3.516667              32.666667                          0.05
# 1            3.190000              33.333333                          0.05
# 2            2.870000              30.000000                          0.13
# 3            3.113333              33.000000                          0.01
# 4            3.116667              33.000000                          0.10
#
#    OXYGEN (%) TOP LEFT  OXYGEN (%) TOP RIGHT  ...  \
# ...

# %%
harman_list.to_excel('harman_liste.xlsx',index=True)

# %%
harman_list = pd.read_excel('harman_liste.xlsx')

# %%
harman_list.head()
# Out:
#    Unnamed: 0       DATE GLASS COLOR  PULL (kg/day)  CULLET (%)  \
# 0           0 2020-01-01       FLINT    445382.0040   10.003913
# 1           1 2020-01-02       FLINT    461392.3982    9.948109
# 2           2 2020-01-03       FLINT    459750.5030   10.004327
# 3           3 2020-01-04       FLINT    441903.0578    8.837440
# 4           4 2020-01-05       FLINT    441964.2880    7.983750
#
#    BATCH HUMIDITY (%)  BATCH TEMPERATURE (C)  FURNACE INLET PRESSURE mmH2O  \
# 0            3.516667              32.666667                          0.05
# 1            3.190000              33.333333                          0.05
# 2            2.870000              30.000000                          0.13
# 3            3.113333              33.000000                          0.01
# 4            3.116667              33.000000                          0.10
#
#    N.GAS consumption Sm3 @15C SM3 @15 C  Net Calorific value of NGas kcal/Sm3  \
# ...

# %%
harman_list.drop(["Unnamed: 0"], axis=1, inplace=True)

# %%
harman_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794 entries, 0 to 793
# Data columns (total 56 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   DATE                                  794 non-null    datetime64[ns]
#  1   GLASS COLOR                           794 non-null    object
#  2   PULL (kg/day)                         794 non-null    float64
#  3   CULLET (%)                            792 non-null    float64
#  4   BATCH HUMIDITY (%)                    794 non-null    float64
#  5   BATCH TEMPERATURE (C)                 794 non-null    float64
#  6   FURNACE INLET PRESSURE mmH2O          794 non-null    float64
#  7   N.GAS consumption Sm3 @15C SM3 @15 C  794 non-null    int64
#  8   Net Calorific value of NGas kcal/Sm3  794 non-null    int64
#  9   NGas consumption kcal/kg              794 non-null    float64
# ...

# %%
df1 = pd.read_excel('veri1.xlsx')

# %%
df1.ASS.fillna(df1.ASS.mean())
df1.ASS.fillna(df1.Müş_Hedef.mean())
mean_value=df1['ASS'].mean()
mean_value1=df1['AUS'].mean()
mean_value2=df1['ÜUS'].mean()
mean_value3=df1['ÜSS'].mean()
mean_value4=df1['Hedef'].mean()
mean_value5=df1['Müş_ASS'].mean()
mean_value6=df1['Müş_ÜSS'].mean()
mean_value7=df1['Müş_Hedef'].mean()

# %%
df1['ASS'].fillna(value=mean_value, inplace=True)
df1['AUS'].fillna(value=mean_value1, inplace=True)
df1['ÜUS'].fillna(value=mean_value2, inplace=True)
df1['ÜSS'].fillna(value=mean_value3, inplace=True)
df1['Hedef'].fillna(value=mean_value4, inplace=True)
df1['Müş_ASS'].fillna(value=mean_value5, inplace=True)
df1['Müş_ÜSS'].fillna(value=mean_value6, inplace=True)
df1['Müş_Hedef'].fillna(value=mean_value7, inplace=True)

# %%
import time
df1['DATE'] = pd.to_datetime(df1['Örneklem_tarihi']).dt.date
df1['Time'] = pd.to_datetime(df1['Örneklem_tarihi']).dt.time

# %%
df1['DATE']=df1['DATE'].astype(str)

# %%
harman_list['DATE']=harman_list['DATE'].astype(str)

# %%
result = pd.merge(df1, harman_list, on = "DATE" )

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 259648 entries, 0 to 259647
# Data columns (total 99 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Fabrika adı                           259648 non-null  object
#  1   Fabrika - Hat                         259648 non-null  object
#  2   Hat                                   259648 non-null  object
#  3   iş_emri                               259648 non-null  object
#  4   Ürün                                  259648 non-null  object
#  5   Ürün_ref                              259648 non-null  int64
#  6   Örneklem_tarihi                       259648 non-null  object
#  7   Kişi                                  259648 non-null  object
#  8   Kontrol_adımı                         259648 non-null  object
#  9   Kontrol_türü                          259648 non-null  object
# ...

# %%
result.to_excel('son_liste.xlsx',index=True)

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
# Out:
# C:\Users\cansu\Anaconda3\lib\site-packages\sklearn\feature_extraction\image.py:167: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype=np.int):

# %%
result = pd.read_excel('son_liste.xlsx')

# %%
result['FURNACE BOTTOM TEMP 820 T/C']= result[' FURNACE BOTTOM TEMP 820 T/C']

# %%
result.fillna(0, inplace=True)

# %%
X = result[['CULLET (%)','BATCH HUMIDITY (%)','GLASS SURFACE (oC)','AIR/FUEL RATIO','FURNACE BOTTOM TEMP 811 T/C','FURNACE BOTTOM TEMP 812 T/C','FURNACE BOTTOM TEMP 815 T/C','FURNACE BOTTOM TEMP 820 T/C']]
y = result['Spesifikasyon_dışı']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.9)

print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)
# Out:
# (186946, 8)
# (51930, 8)
# (20772, 8)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
from sklearn import linear_model
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# C:\Users\cansu\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\cansu\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
z_pred = regr.predict(X_test)

# %%
score=r2_score(y_test,z_pred)
print('r2 score is',score)
# Out:
# r2 score is 0.10657591247291065

# %%
z_pred = regr.predict(X_valid)

# %%
score=r2_score(y_valid,z_pred)
print('r2 score is',score)
# Out:
# r2 score is 0.11087966115089154

# %%
X = sm.add_constant(X_test) # adding a constant
 
model = sm.OLS(y_test, X_test).fit()
predictions = model.predict(X_test) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     Spesifikasyon_dışı   R-squared:                       0.104
# Model:                            OLS   Adj. R-squared:                  0.104
# Method:                 Least Squares   F-statistic:                     751.8
# Date:                Sun, 27 Feb 2022   Prob (F-statistic):               0.00
# Time:                        14:39:49   Log-Likelihood:                -49831.
# No. Observations:               51930   AIC:                         9.968e+04
# Df Residuals:                   51921   BIC:                         9.976e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           3.3424      0.296     11.280      0.000       2.762       3.923
# ...

# %%
#result = pd.read_excel('veri1.xlsx')

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259648 entries, 0 to 259647
# Data columns (total 99 columns):
#  #   Column                                Non-Null Count   Dtype
# ---  ------                                --------------   -----
#  0   Unnamed: 0                            259648 non-null  int64
#  1   Fabrika adı                           259648 non-null  object
#  2   Fabrika - Hat                         259648 non-null  object
#  3   Hat                                   259648 non-null  object
#  4   iş_emri                               259648 non-null  object
#  5   Ürün                                  259648 non-null  object
#  6   Ürün_ref                              259648 non-null  int64
#  7   Örneklem_tarihi                       259648 non-null  object
#  8   Kişi                                  259648 non-null  object
#  9   Kontrol_adımı                         259648 non-null  object
# ...

# %%
result['FURNACE BOTTOM TEMP 820 T/C']= result[' FURNACE BOTTOM TEMP 820 T/C']

# %%
result.fillna(0, inplace=True)

# %%
X = result[['CULLET (%)','BATCH HUMIDITY (%)','GLASS SURFACE (oC)','AIR/FUEL RATIO','FURNACE BOTTOM TEMP 811 T/C','FURNACE BOTTOM TEMP 812 T/C','FURNACE BOTTOM TEMP 815 T/C','FURNACE BOTTOM TEMP 820 T/C']]
y = result['Spesifikasyon_dışı']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.9)

print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)
# Out:
# (186946, 8)
# (51930, 8)
# (20772, 8)

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
z_pred = regr.predict(X_test)

# %%
score=r2_score(y_test,z_pred)
print('r2 score is',score)
# Out:
# r2 score is 0.10266788178294262

# %%
z_pred = regr.predict(X_valid)

# %%
score=r2_score(y_valid,z_pred)
print('r2 score is',score)
# Out:
# r2 score is 0.10374727626470559

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
ols = linear_model.LinearRegression()
model = ols.fit(X, y)
model.score(X, y)
# Out:
# 0.10597641701670069

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:     Spesifikasyon_dışı   R-squared:                       0.106
# Model:                            OLS   Adj. R-squared:                  0.106
# Method:                 Least Squares   F-statistic:                     3847.
# Date:                Sun, 20 Feb 2022   Prob (F-statistic):               0.00
# Time:                        20:55:43   Log-Likelihood:            -2.4800e+05
# No. Observations:              259648   AIC:                         4.960e+05
# Df Residuals:                  259639   BIC:                         4.961e+05
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                   coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           3.2110      0.131     24.427      0.000       2.953       3.469
# ...

# %%
A = result[['TiO2','SiO2','Al2O3','Fe2O3','CaO','MgO','Na2O','K2O','SO3','Cr2O3','Pb (ppm)','Fe+2','Fe+2 / Fe2O3']]
B = result['Spesifikasyon_dışı']

# %%
X_train, X_test, y_train, y_test = train_test_split(A, B, train_size=0.8)

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.9)

print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)
# Out:
# (186946, 13)
# (51930, 13)
# (20772, 13)

# %%
regr = linear_model.LinearRegression()
regr.fit(A, B)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
z_pred = regr.predict(X_test)

# %%
score=r2_score(y_test,z_pred)
print('r2 score is',score)
# Out:
# r2 score is 0.11661432964847118

# %%
z_pred = regr.predict(X_valid)

# %%
score=r2_score(y_valid,z_pred)
print('r2 score is',score)
# Out:
# r2 score is 0.11847893746794647

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(A, B, test_size = 0.4, random_state = 0)

# %%
from sklearn import linear_model

# %%
regr = linear_model.LinearRegression()
regr.fit(A, B)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print(regr.coef_)
# Out:
# [-1.59779077  0.00939945  0.02135218 -0.75007586 -0.93791733 -5.39276308
#  -0.04872284 -0.11837411 -1.08855532  2.18385242 -0.00995623 -0.0059824
#  -0.01063506]

# %%
from sklearn import linear_model

ols = linear_model.LinearRegression()
model = ols.fit(A, B)
model.score(A, B)
# Out:
# 0.11811953227319472

# %%
z_pred = regr.predict(X_test)

# %%
score=r2_score(y_test,z_pred)
print('r2 score is',score)
print('mean_sqrd_error is==',mean_squared_error(y_test,z_pred))
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,z_pred)))
# Out:
# r2 score is 0.11906247555393201
# mean_sqrd_error is== 0.38975838837200677
# root_mean_squared error of is== 0.6243063257504338

# %%
A = sm.add_constant(A) # adding a constant
 
model = sm.OLS(B, A).fit()
predictions = model.predict(A) 
 
print_model = model.summary()
print(print_model)
# Out:
# C:\Users\cansu\Anaconda3\lib\site-packages\statsmodels\tsa\tsatools.py:117: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)
#                             OLS Regression Results
# ...
# Dep. Variable:     Spesifikasyon_dışı   R-squared:                       0.118
# Model:                            OLS   Adj. R-squared:                  0.118
# Method:                 Least Squares   F-statistic:                     2675.
# Date:                Sun, 27 Feb 2022   Prob (F-statistic):               0.00
# Time:                        18:55:58   Log-Likelihood:            -2.4622e+05
# No. Observations:              259648   AIC:                         4.925e+05
# Df Residuals:                  259634   BIC:                         4.926e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ...

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
# predicting the accuracy score

# %%
# Import label encoder
from sklearn import preprocessing
 
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
 
# Encode labels in column 'species'.
result['COLOR']= label_encoder.fit_transform(result['GLASS COLOR'])
 
result['COLOR'].unique()
# Out:
# array([1, 0, 2, 3])

# %%
X = result[['BATCH HUMIDITY (%)','GLASS SURFACE (oC)','SiO2','TiO2','Al2O3','Fe2O3','CaO','MgO','Na2O','K2O','SO3','Cr2O3','Pb (ppm)']]
y = result['COLOR']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8)

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.9)

print(X_train.shape)
print(X_test.shape)
print(X_valid.shape)
# Out:
# (186946, 13)
# (51930, 13)
# (20772, 13)

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
z_pred = regr.predict(X_test)

# %%
score=r2_score(y_test,z_pred)
print('r2 score is',score)
# Out:
# r2 score is 0.9769647816902773

# %%
z_pred = regr.predict(X_valid)

# %%
score=r2_score(y_valid,z_pred)
print('r2 score is',score)
# Out:
# r2 score is 0.9774867354698784

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.4, random_state = 0)

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
ols = linear_model.LinearRegression()
model = ols.fit(X, y)
model.score(X, y)
# Out:
# 0.9769904972876665

# %%
z_pred = regr.predict(X_test)

# %%
score=r2_score(y_test,z_pred)
print('r2 score is',score)
print('mean_sqrd_error is==',mean_squared_error(y_test,z_pred))
print('root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,z_pred)))
# Out:
# r2 score is 0.9770259074952464
# mean_sqrd_error is== 0.012618576822218164
# root_mean_squared error of is== 0.11233243886882437

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                       0.977
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                 8.480e+05
# Date:                Mon, 10 Jan 2022   Prob (F-statistic):               0.00
# Time:                        22:43:55   Log-Likelihood:             1.9893e+05
# No. Observations:              259648   AIC:                        -3.978e+05
# Df Residuals:                  259634   BIC:                        -3.977e+05
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  5.6529      0.063     90.026      0.000       5.530       5.776
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
# Out:
# C:\Users\cansu\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\cansu\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = result['BATCH HUMIDITY (%)']
y = result['BUBBLER (per minute)']
x_array = np.array(x).reshape((-1, 1))
y_array = np.array(y).reshape((-1, 1))

# %%
x_train, x_test, y_train, y_test = train_test_split(x_array,y_array,test_size=0.33,random_state=0)

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(x_test)

# %%
sc= StandardScaler()

# %%
X_train = sc.fit_transform(x_train)
X_test = sc.fit_transform(x_test)

# %%
regressor.score(x_array,y_array)
# Out:
# 0.3100031273413466

# %%
lr =  LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred = lr.predict(X_test)

# %%
import matplotlib.pyplot as plt
plt.title('Batch Humidity vs Bubbler per minute')
plt.xlabel("Batch Humidity", fontsize=14)
plt.ylabel('Bubbler per minute', fontsize=14)
plt.scatter(x_train,y_train)

# %%
plt.plot(x_test,lr.predict(x_test))

# %%
# Import label encoder
from sklearn import preprocessing
 
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()
 
# Encode labels in column 'species'.
harman_list['COLOR']= label_encoder.fit_transform(harman_list['GLASS COLOR'])
 
harman_list['COLOR'].unique()
# Out:
# array([1, 2, 0, 3])

# %%
harman_list.fillna(0, inplace=True)

# %%
from sklearn import linear_model

# %%
X = harman_list[['SiO2','TiO2','Al2O3','Fe2O3','CaO','MgO','Na2O','K2O','SO3','Cr2O3','Pb (ppm)']]
y = harman_list['COLOR']

# %%
harman_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 914 entries, 0 to 913
# Data columns (total 58 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Unnamed: 0                            914 non-null    int64
#  1   DATE                                  914 non-null    datetime64[ns]
#  2   GLASS COLOR                           914 non-null    object
#  3   PULL (kg/day)                         914 non-null    float64
#  4   CULLET (%)                            914 non-null    float64
#  5   BATCH HUMIDITY (%)                    914 non-null    float64
#  6   BATCH TEMPERATURE (C)                 914 non-null    float64
#  7   FURNACE INLET PRESSURE mmH2O          914 non-null    float64
#  8   N.GAS consumption Sm3 @15C SM3 @15 C  914 non-null    int64
#  9   Net Calorific value of NGas kcal/Sm3  914 non-null    int64
# ...

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                       0.974
# Model:                            OLS   Adj. R-squared:                  0.974
# Method:                 Least Squares   F-statistic:                     3082.
# Date:                Mon, 10 Jan 2022   Prob (F-statistic):               0.00
# Time:                        21:00:58   Log-Likelihood:                 343.31
# No. Observations:                 914   AIC:                            -662.6
# Df Residuals:                     902   BIC:                            -604.8
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          5.5176      1.186      4.651      0.000       3.189       7.846
# ...

# %%
X = harman_list[['TiO2','Al2O3','Fe2O3','CaO','MgO','Na2O','K2O','SO3','Cr2O3','Pb (ppm)']]
y = harman_list['COLOR']

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                     2184.
# Date:                Mon, 10 Jan 2022   Prob (F-statistic):               0.00
# Time:                        20:10:13   Log-Likelihood:                 308.27
# No. Observations:                 794   AIC:                            -594.5
# Df Residuals:                     783   BIC:                            -543.1
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.3210      1.238      3.492      0.001       1.892       6.750
# ...

# %%
X = harman_list[['TiO2','Al2O3','Fe2O3','CaO','MgO','K2O','SO3','Cr2O3','Pb (ppm)']]
y = harman_list['COLOR']

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                       0.965
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                     2422.
# Date:                Mon, 10 Jan 2022   Prob (F-statistic):               0.00
# Time:                        20:10:36   Log-Likelihood:                 307.01
# No. Observations:                 794   AIC:                            -594.0
# Df Residuals:                     784   BIC:                            -547.3
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.6977      1.174      3.151      0.002       1.394       6.001
# ...

# %%
X = result[['CULLET (%)']]
y = result['COLOR']

# %%
from sklearn import linear_model
# Out:
# C:\Users\cansu\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# C:\Users\cansu\Anaconda3\lib\site-packages\sklearn\linear_model\least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
regr = linear_model.LinearRegression()
regr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
ols = linear_model.LinearRegression()
model = ols.fit(X, y)
model.score(X, y)
# Out:
# 0.2777121294571261

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# C:\Users\cansu\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                       0.278
# Model:                            OLS   Adj. R-squared:                  0.278
# Method:                 Least Squares   F-statistic:                 9.983e+04
# Date:                Thu, 03 Mar 2022   Prob (F-statistic):               0.00
# Time:                        14:28:19   Log-Likelihood:            -2.4851e+05
# No. Observations:              259648   AIC:                         4.970e+05
# Df Residuals:                  259646   BIC:                         4.970e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...

# %%
amber = result[result["GLASS COLOR"] == 'AMBER']

# %%
X = amber[['SiO2','TiO2','Al2O3','Fe2O3','CaO','MgO','Na2O','K2O','SO3','Cr2O3','Pb (ppm)']]
y = amber['COLOR']

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Mon, 10 Jan 2022   Prob (F-statistic):                nan
# Time:                        22:55:24   Log-Likelihood:                    inf
# No. Observations:                3268   AIC:                              -inf
# Df Residuals:                    3261   BIC:                              -inf
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const               0          0        nan        nan           0           0
# ...

# %%
flint = harman_list[harman_list["GLASS COLOR"] == 'FLINT']

# %%
ir_green = harman_list[harman_list["GLASS COLOR"] == 'IR-GREEN']

# %%
uv_green = harman_list[harman_list["GLASS COLOR"] == 'UV-GREEN']

# %%
X = flint[['BATCH HUMIDITY (%)','GLASS SURFACE (oC)','SiO2','TiO2','Al2O3','Fe2O3','CaO','MgO','Na2O','K2O','SO3','Cr2O3','Pb (ppm)']]
y = flint['COLOR']

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                        -inf
# Model:                            OLS   Adj. R-squared:                   -inf
# Method:                 Least Squares   F-statistic:                    -15.42
# Date:                Mon, 10 Jan 2022   Prob (F-statistic):               1.00
# Time:                        21:17:17   Log-Likelihood:                 6127.9
# No. Observations:                 198   AIC:                        -1.223e+04
# Df Residuals:                     185   BIC:                        -1.219e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0010   2.44e-14   4.09e+10      0.000       0.001       0.001
# ...

# %%
X = ir_green[['BATCH HUMIDITY (%)','GLASS SURFACE (oC)','SiO2','TiO2','Al2O3','Fe2O3','CaO','MgO','Na2O','K2O','SO3','Cr2O3','Pb (ppm)']]
y = ir_green['COLOR']

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                        -inf
# Model:                            OLS   Adj. R-squared:                   -inf
# Method:                 Least Squares   F-statistic:                    -27.08
# Date:                Mon, 10 Jan 2022   Prob (F-statistic):               1.00
# Time:                        21:17:30   Log-Likelihood:                 10025.
# No. Observations:                 338   AIC:                        -2.002e+04
# Df Residuals:                     325   BIC:                        -1.997e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.0020   1.55e-14   1.29e+11      0.000       0.002       0.002
# ...

# %%
X = uv_green[['BATCH HUMIDITY (%)','GLASS SURFACE (oC)','SiO2','TiO2','Al2O3','Fe2O3','CaO','MgO','Na2O','K2O','SO3','Cr2O3','Pb (ppm)']]
y = uv_green['COLOR']

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                        -inf
# Model:                            OLS   Adj. R-squared:                   -inf
# Method:                 Least Squares   F-statistic:                    -14.15
# Date:                Mon, 10 Jan 2022   Prob (F-statistic):               1.00
# Time:                        21:17:47   Log-Likelihood:                 5410.3
# No. Observations:                 198   AIC:                        -1.079e+04
# Df Residuals:                     184   BIC:                        -1.075e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  3.0000    3.5e-10   8.57e+09      0.000       3.000       3.000
# ...

# %%
X = uv_green[['SiO2','TiO2','Al2O3','CaO','MgO','Na2O','K2O','SO3','Cr2O3','Pb (ppm)']]
y = uv_green['COLOR']

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                        -inf
# Model:                            OLS   Adj. R-squared:                   -inf
# Method:                 Least Squares   F-statistic:                    -18.70
# Date:                Mon, 10 Jan 2022   Prob (F-statistic):               1.00
# Time:                        20:13:22   Log-Likelihood:                 5802.3
# No. Observations:                 198   AIC:                        -1.158e+04
# Df Residuals:                     187   BIC:                        -1.155e+04
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.0000   2.01e-12   1.49e+12      0.000       3.000       3.000
# ...

# %%
X = uv_green[['SiO2','TiO2','Al2O3','CaO','MgO','Na2O','K2O','Cr2O3','Pb (ppm)']]
y = uv_green['COLOR']

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                        -inf
# Model:                            OLS   Adj. R-squared:                   -inf
# Method:                 Least Squares   F-statistic:                    -20.89
# Date:                Mon, 10 Jan 2022   Prob (F-statistic):               1.00
# Time:                        20:13:49   Log-Likelihood:                 5996.2
# No. Observations:                 198   AIC:                        -1.197e+04
# Df Residuals:                     188   BIC:                        -1.194e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.0000   7.51e-13   3.99e+12      0.000       3.000       3.000
# ...

# %%
gk = result.groupby('GLASS COLOR')

# %%
result
# Out:
#         Unnamed: 0 Fabrika adı   Fabrika - Hat Hat     iş_emri  \
# 0                0   Yenisehir  Yenisehir - C4  C4  61C4200002
# 1                1   Yenisehir  Yenisehir - C4  C4  61C4200002
# 2                2   Yenisehir  Yenisehir - C4  C4  61C4200002
# 3                3   Yenisehir  Yenisehir - C4  C4  61C4200002
# 4                4   Yenisehir  Yenisehir - C4  C4  61C4200002
# ...            ...         ...             ...  ..         ...
# 259643      259643   Yenisehir  Yenisehir - C4  C4  61C4200029
# 259644      259644   Yenisehir  Yenisehir - C4  C4  61C4200029
# 259645      259645   Yenisehir  Yenisehir - C4  C4  61C4200029
# 259646      259646   Yenisehir  Yenisehir - C4  C4  61C4200029
# 259647      259647   Yenisehir  Yenisehir - C4  C4  61C4200029
#
#                                            Ürün  Ürün_ref    Örneklem_tarihi  \
# 0                           529499-1 L WINE STD    529499  7.1.2020 14:35:36
# ...

# %%
X = harman_list[['CULLET (%)','BATCH HUMIDITY (%)','GLASS SURFACE (oC)','TiO2','Al2O3','Fe2O3','CaO','MgO','Na2O','K2O','SO3','Cr2O3','Pb (ppm)','Fe+2']]
y = harman_list['COLOR']

# %%
print(regr.coef_)
# Out:
# [-1.59779077  0.00939945  0.02135218 -0.75007586 -0.93791733 -5.39276308
#  -0.04872284 -0.11837411 -1.08855532  2.18385242 -0.00995623 -0.0059824
#  -0.01063506]

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                       0.969
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     1711.
# Date:                Tue, 04 Jan 2022   Prob (F-statistic):               0.00
# Time:                        22:15:33   Log-Likelihood:                 345.78
# No. Observations:                 794   AIC:                            -661.6
# Df Residuals:                     779   BIC:                            -591.4
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  6.3774      1.332      4.787      0.000       3.762       8.993
# ...

# %%
X = harman_list[['CULLET (%)','BATCH HUMIDITY (%)','GLASS SURFACE (oC)','TiO2','Al2O3','Fe2O3','CaO','Na2O','K2O','SO3','Cr2O3','Pb (ppm)','Fe+2']]
y = harman_list['COLOR']

# %%
print(regr.coef_)
# Out:
# [-1.59779077  0.00939945  0.02135218 -0.75007586 -0.93791733 -5.39276308
#  -0.04872284 -0.11837411 -1.08855532  2.18385242 -0.00995623 -0.0059824
#  -0.01063506]

# %%
import statsmodels.api as sm
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  COLOR   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     1843.
# Date:                Tue, 04 Jan 2022   Prob (F-statistic):               0.00
# Time:                        22:16:29   Log-Likelihood:                 345.24
# No. Observations:                 794   AIC:                            -662.5
# Df Residuals:                     780   BIC:                            -597.0
# Df Model:                          13
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  7.0946      1.135      6.249      0.000       4.866       9.323
# ...

# %%
gk = harman_list.groupby('GLASS COLOR')

# %%
gk.first().T
# Out:
# GLASS COLOR                                 AMBER        FLINT     IR-GREEN  \
# DATE                                   2020-05-19   2020-01-01   2020-01-01
# PULL (kg/day)                         462075.0125   445382.004   494166.872
# CULLET (%)                              19.993403    10.003913    59.998719
# BATCH HUMIDITY (%)                       3.316667     3.516667         3.23
# BATCH TEMPERATURE (C)                        41.0    32.666667         36.0
# FURNACE INLET PRESSURE mmH2O                -1.02         0.05        -1.01
# N.GAS consumption Sm3 @15C SM3 @15 C        52452        53527        48490
# Net Calorific value of NGas kcal/Sm3         8250         8250         8250
# NGas consumption kcal/kg               936.490804   991.503352   809.529175
# AIR/FUEL RATIO                                9.6         10.3         10.0
# Electric Boost Zone1                        14770        11945         9750
# ...

# %%
amber = gk.get_group('AMBER')

# %%
flint = gk.get_group('FLINT')

# %%
irgreen = gk.get_group('IR-GREEN')

# %%
uvgreen = gk.get_group('UV-GREEN')

# %%
import scipy.stats
scipy.stats.chisquare(harman_list["GLASS COLOR"].value_counts())
# Out:
# Power_divergenceResult(statistic=194.6750629722922, pvalue=5.965630433149014e-42)

# %%
harman_list['CULLET']=harman_list['CULLET (%)'].dropna().astype('int')

# %%
harman_list['CULLET']= harman_list['CULLET'].replace(0,harman_list['CULLET'].mean())

# %%
harman_list = harman_list.fillna(0)

# %%
harman_list.CULLET.astype(int)
# Out:
# 0      10
# 1       9
# 2      10
# 3       8
# 4       7
#        ..
# 789    49
# 790    49
# 791    49
# 792    49
# 793    50
# Name: CULLET, Length: 794, dtype: int32

# %%
harman_list.CULLET.groupby(harman_list.COLORS).mean()
# Out:
# COLORS
# AMBER       40.158564
# FLINT       13.000000
# IR-GREEN    65.326964
# UV-GREEN    46.287879
# Name: CULLET, dtype: float64

# %%
harman_list['COLORS']=harman_list['GLASS COLOR'].dropna()

# %%
import scipy.stats as stats

# %%
amber = harman_list[harman_list.COLORS == 'AMBER']
flint = harman_list[harman_list.COLORS == 'FLINT']
ir_green = harman_list[harman_list.COLORS == 'IR-GREEN']
uv_green = harman_list[harman_list.COLORS == 'UV-GREEN']

# %%
stats.f_oneway(amber.CULLET,flint.CULLET,ir_green.CULLET,uv_green.CULLET)
# Out:
# F_onewayResult(statistic=1920.5765080530227, pvalue=0.0)

# %%
r = harman_list.groupby("GLASS COLOR").mean()

# %%
print(r)
# Out:
#              PULL (kg/day)  CULLET (%)  BATCH HUMIDITY (%)  \
# GLASS COLOR
# AMBER        337668.596873   39.926154            2.518095
# FLINT        420131.655420   13.476146            2.800249
# IR-GREEN     409514.115410   65.849991            3.382891
# UV-GREEN     218174.751719   25.990221            1.840395
#
#              BATCH TEMPERATURE (C)  FURNACE INLET PRESSURE mmH2O  \
# GLASS COLOR
# AMBER                    38.079365                     -0.922381
# FLINT                    33.088597                      0.043960
# IR-GREEN                 35.383187                     -0.299214
# UV-GREEN                 20.193078                      0.021842
#
#              OXYGEN (%) TOP LEFT  OXYGEN (%) TOP RIGHT  \
# GLASS COLOR
# AMBER                   2.154545              2.300000
# FLINT                   3.400000              3.420690
# IR-GREEN                2.572340              2.623404
# UV-GREEN                3.216129              3.506452
#
# ...

# %%
s = harman_list.groupby("GLASS COLOR")["PULL (kg/day)"].mean()

# %%
print(s)
# Out:
# GLASS COLOR
# AMBER       337668.596873
# FLINT       420131.655420
# IR-GREEN    409514.115410
# UV-GREEN    218174.751719
# Name: PULL (kg/day), dtype: float64

# %%
max = harman_list.groupby("GLASS COLOR")["PULL (kg/day)"].max()
max
# Out:
# GLASS COLOR
# AMBER       481601.2800
# FLINT       488130.4780
# IR-GREEN    509052.2400
# UV-GREEN    414503.1076
# Name: PULL (kg/day), dtype: float64

# %%
min = harman_list.groupby("GLASS COLOR")["PULL (kg/day)"].min()
min
# Out:
# GLASS COLOR
# AMBER       0.0
# FLINT       0.0
# IR-GREEN    0.0
# UV-GREEN    0.0
# Name: PULL (kg/day), dtype: float64

# %%
harman_list.notnull()
# Out:
#       DATE  GLASS COLOR  PULL (kg/day)  CULLET (%)  BATCH HUMIDITY (%)  \
# 0     True         True           True        True                True
# 1     True         True           True        True                True
# 2     True         True           True        True                True
# 3     True         True           True        True                True
# 4     True         True           True        True                True
# ...    ...          ...            ...         ...                 ...
# 1459  True         True           True        True                True
# 1460  True         True           True        True                True
# 1461  True         True           True        True                True
# 1462  True         True           True        True                True
# 1463  True         True           True        True                True
#
#       BATCH TEMPERATURE (C)  FURNACE INLET PRESSURE mmH2O  \
# ...

# %%
harman_list.dropna(how="all")
# Out:
#            DATE GLASS COLOR  PULL (kg/day)  CULLET (%)  BATCH HUMIDITY (%)  \
# 0    2020-01-01       FLINT    445382.0040   10.003913            3.516667
# 1    2020-01-02       FLINT    461392.3982    9.948109            3.190000
# 2    2020-01-03       FLINT    459750.5030   10.004327            2.870000
# 3    2020-01-04       FLINT    441903.0578    8.837440            3.113333
# 4    2020-01-05       FLINT    441964.2880    7.983750            3.116667
# ...         ...         ...            ...         ...                 ...
# 1459 2020-12-27    UV-GREEN         0.0000    0.000000            0.000000
# 1460 2020-12-28    UV-GREEN         0.0000    0.000000            0.000000
# 1461 2020-12-29    UV-GREEN         0.0000    0.000000            0.000000
# 1462 2020-12-30    UV-GREEN         0.0000    0.000000            0.000000
# 1463 2020-12-31    UV-GREEN         0.0000    0.000000            0.000000
#
#       BATCH TEMPERATURE (C)  FURNACE INLET PRESSURE mmH2O  \
# ...
